# %% [markdown]
# ### Guided Practice: Logit Function and Odds

# %%
def logit_func(odds):
    # uses a float (odds) and returns back the log odds (logit)
    return None

def sigmoid_func(logit):
    # uses a float (logit) and returns back the probability
    return None

odds_set = [
    5./1,
    20./1,
    1.1/1,
    1.8/1,
    1.6/1
]

# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression

# %%
lm = LogisticRegression()

df = pd.read_csv('/Users/vvnikitin/Desktop/admissions.csv')

# %%
df.head()
# Out:
#    admit    gre   gpa  prestige
# 0      0  380.0  3.61       3.0
# 1      1  660.0  3.67       3.0
# 2      1  800.0  4.00       1.0
# 3      1  640.0  3.19       4.0
# 4      0  520.0  2.93       4.0

# %%
df = df.join(pd.get_dummies(df['rank']))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-7685c701d615> in <module>()
# ----> 1 df = df.join(pd.get_dummies(df['rank']))
#
# /anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1962             return self._getitem_multilevel(key)
#    1963         else:
# -> 1964             return self._getitem_column(key)
#    1965
#    1966     def _getitem_column(self, key):
#
# /anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    1969         # get column
#    1970         if self.columns.is_unique:
# -> 1971             return self._get_item_cache(key)
#    1972
#    1973         # duplicate columns & possible reduce dimensionality
#
# /anaconda2/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1643         res = cache.get(item)
#    1644         if res is None:
# -> 1645             values = self._data.get(item)
#    1646             res = self._box_item_values(item, values)
#    1647             cache[item] = res
#
# /anaconda2/lib/python2.7/site-packages/pandas/core/internals.pyc in get(self, item, fastpath)
#    3588
#    3589             if not isnull(item):
# -> 3590                 loc = self.items.get_loc(item)
#    3591             else:
#    3592                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /anaconda2/lib/python2.7/site-packages/pandas/core/indexes/base.pyc in get_loc(self, key, method, tolerance)
#    2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
# -> 2444                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2445
#    2446         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'rank'

# %%
df.head()
# Out:
#    admit    gre   gpa  prestige
# 0      0  380.0  3.61       3.0
# 1      1  660.0  3.67       3.0
# 2      1  800.0  4.00       1.0
# 3      1  640.0  3.19       4.0
# 4      0  520.0  2.93       4.0

# %%
lm.fit(df['gre', 'gpa', 1, 2, 3], df['admit'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-7cfb6976141f> in <module>()
# ----> 1 lm.fit(df['gre', 'gpa', 1, 2, 3], df['admit'])
#
# /anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1962             return self._getitem_multilevel(key)
#    1963         else:
# -> 1964             return self._getitem_column(key)
#    1965
#    1966     def _getitem_column(self, key):
#
# /anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    1969         # get column
#    1970         if self.columns.is_unique:
# -> 1971             return self._get_item_cache(key)
#    1972
#    1973         # duplicate columns & possible reduce dimensionality
#
# /anaconda2/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1643         res = cache.get(item)
#    1644         if res is None:
# -> 1645             values = self._data.get(item)
#    1646             res = self._box_item_values(item, values)
#    1647             cache[item] = res
#
# /anaconda2/lib/python2.7/site-packages/pandas/core/internals.pyc in get(self, item, fastpath)
#    3588
#    3589             if not isnull(item):
# -> 3590                 loc = self.items.get_loc(item)
#    3591             else:
#    3592                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /anaconda2/lib/python2.7/site-packages/pandas/core/indexes/base.pyc in get_loc(self, key, method, tolerance)
#    2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
# -> 2444                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2445
#    2446         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('gre', 'gpa', 1, 2, 3)

# %%
import numpy as np

# %%
print lm.coef_
print lm.intercept_
print df.admit.mean()
# Out:
# [[  1.63913356e-03   4.33354115e-04   1.15220976e+00   5.14395667e-01
#    -3.62326171e-02]]
# [ 0.12329791]
# 0.3175

# %% [markdown]
# Below is some code to walk through confusion matrices. It'll be useful for working through the Titanic problem.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, roc_auc_score

# %% [markdown]
# Below the ROC curve is based on various thresholds: it shows with a false positive rate (x-axis) ~0, it also expects a true positive rate (y-axis) ~0 (the same, ish, for the top right hand of the figure).
#
# The second chart, which does not play with thesholds, shows the one true TPR and FPR point, joined to 0,0 and 1,1.
#
# The first chart will be more effective as you compare models and determine where the decision line should exist for the data. The second simplifies the first in case this idea of thresholds is confusing.

# %%
actuals = lm.predict(feature_set) 
probas = lm.predict_proba(feature_set)
plt.plot(roc_curve(df[['admit']], probas[:,1])[0], roc_curve(df[['admit']], probas[:,1])[1])

# %%
plt.plot(roc_curve(df[['admit']], actuals)[0], roc_curve(df[['admit']], actuals)[1])

# %% [markdown]
# Finally, you can use the `roc_auc_score` function to calculate the area under these curves (AUC).

# %%
roc_auc_score(df['admit'], lm.predict(feature_set)
# Out:
# 0.55914164575581893

# %% [markdown]
# ### Titanic Problem

# %% [markdown]
# ** Goals **
#
# 1. Spend a few minutes determining which data would be most important to use in the prediction problem. You may need to create new features based on the data available. Consider using a feature selection aide in sklearn. But a worst case scenario; identify one or two strong features that would be useful to include in the model.
# 2. Spend 1-2 minutes considering which _metric_ makes the most sense to optimize. Accuracy? FPR or TPR? AUC? Given the business problem (understanding survival rate aboard the Titanic), why should you use this metric?
# 3. Build a tuned Logistic model. Be prepared to explain your design (including regularization), metric, and feature set in predicting survival using the tools necessary (such as a fit chart).

# %%
titanic_data = pd.read_csv('/Users/vvnikitin/Desktop/titanic.csv')

# %%
titanic_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
model_data.Age = model_data.Age.fillna(method='bfill')

# %%
cols_to_keep =['Survived', 'Pclass', 'Sex','Age', 'SibSp', 'Parch']
model_data = titanic_data[cols_to_keep].copy()
print model_data.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# dtype: int64

# %%
import seaborn as sns
sns.pairplot(titanic_data[cols_to_keep])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-f1c8075c08f2> in <module>()
#       1 import seaborn as sns
# ----> 2 sns.pairplot(titanic_data[cols_to_keep])
#
# /anaconda2/lib/python2.7/site-packages/seaborn/axisgrid.pyc in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, size, aspect, dropna, plot_kws, diag_kws, grid_kws)
#    2036     if grid.square_grid:
#    2037         if diag_kind == "hist":
# -> 2038             grid.map_diag(plt.hist, **diag_kws)
#    2039         elif diag_kind == "kde":
#    2040             diag_kws["legend"] = False
#
# /anaconda2/lib/python2.7/site-packages/seaborn/axisgrid.pyc in map_diag(self, func, **kwargs)
#    1352                 else:
#    1353                     func(vals, color=color, histtype="barstacked",
# -> 1354                          **kwargs)
#    1355             else:
#    1356                 for k, label_k in enumerate(self.hue_names):
#
# /anaconda2/lib/python2.7/site-packages/matplotlib/pyplot.pyc in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, normed, hold, data, **kwargs)
#    3002                       histtype=histtype, align=align, orientation=orientation,
#    3003                       rwidth=rwidth, log=log, color=color, label=label,
# -> 3004                       stacked=stacked, normed=normed, data=data, **kwargs)
#    3005     finally:
#    3006         ax._hold = washold
#
# /anaconda2/lib/python2.7/site-packages/matplotlib/__init__.pyc in inner(ax, *args, **kwargs)
#    1708                     warnings.warn(msg % (label_namer, func.__name__),
#    1709                                   RuntimeWarning, stacklevel=2)
# -> 1710             return func(ax, *args, **kwargs)
#    1711         pre_doc = inner.__doc__
#    1712         if pre_doc is None:
#
# /anaconda2/lib/python2.7/site-packages/matplotlib/axes/_axes.pyc in hist(***failed resolving arguments***)
#    6205             # this will automatically overwrite bins,
#    6206             # so that each histogram uses the same bins
# -> 6207             m, bins = np.histogram(x[i], bins, weights=w[i], **hist_kwargs)
#    6208             m = m.astype(float)  # causes problems later if it's an int
#    6209             if mlast is None:
#
# /anaconda2/lib/python2.7/site-packages/numpy/lib/function_base.pyc in histogram(a, bins, range, normed, weights, density)
#     665     if mn > mx:
#     666         raise ValueError(
# --> 667             'max must be larger than min in range parameter.')
#     668     if not np.all(np.isfinite([mn, mx])):
#     669         raise ValueError(
#
# ValueError: max must be larger than min in range parameter.

# %%
sns.factorplot(kind = 'box', data=model_data, x = "Survived", y = 'Age')

# %%
model_data['isSibling'] = model_data['SibSp'].apply(lambda x: int(x>0))
model_data['isChild'] = model_data['Parch'].apply(lambda x: int(x>0))
pd.get_dummies(data = model_data, columns = ['Sex',"Pclass"], drop_first=True)
# Out:
#      Survived   Age  SibSp  Parch  isSibling  isChild  Sex_male  Pclass_2  \
# 0           0  22.0      1      0          1        0         1         0
# 1           1  38.0      1      0          1        0         0         0
# 2           1  26.0      0      0          0        0         0         0
# 3           1  35.0      1      0          1        0         0         0
# 4           0  35.0      0      0          0        0         1         0
# 5           0  54.0      0      0          0        0         1         0
# 6           0  54.0      0      0          0        0         1         0
# 7           0   2.0      3      1          1        1         1         0
# 8           1  27.0      0      2          0        1         0         0
# 9           1  14.0      1      0          1        0         0         1
# 10          1   4.0      1      1          1        1         0         0
# 11          1  58.0      0      0          0        0         0         0
# 12          0  20.0      0      0          0        0         1         0
# 13          0  39.0      1      5          1        1         1         0
# 14          0  14.0      0      0          0        0         0         0
# 15          1  55.0      0      0          0        0         0         1
# 16          0   2.0      4      1          1        1         1         0
# 17          1  31.0      0      0          0        0         1         1
# 18          0  31.0      1      0          1        0         0         0
# 19          1  35.0      0      0          0        0         0         0
# 20          0  35.0      0      0          0        0         1         1
# 21          1  34.0      0      0          0        0         1         1
# 22          1  15.0      0      0          0        0         0         0
# 23          1  28.0      0      0          0        0         1         0
# 24          0   8.0      3      1          1        1         0         0
# 25          1  38.0      1      5          1        1         0         0
# 26          0  19.0      0      0          0        0         1         0
# 27          0  19.0      3      2          1        1         1         0
# 28          1  40.0      0      0          0        0         0         0
# 29          0  40.0      0      0          0        0         1         0
# ..        ...   ...    ...    ...        ...      ...       ...       ...
# 861         0  21.0      1      0          1        0         1         1
# 862         1  48.0      0      0          0        0         0         0
# 863         0  24.0      8      2          1        1         0         0
# 864         0  24.0      0      0          0        0         1         1
# 865         1  42.0      0      0          0        0         0         1
# 866         1  27.0      1      0          1        0         0         1
# 867         0  31.0      0      0          0        0         1         0
# 868         0   4.0      0      0          0        0         1         0
# 869         1   4.0      1      1          1        1         1         0
# 870         0  26.0      0      0          0        0         1         0
# 871         1  47.0      1      1          1        1         0         0
# 872         0  33.0      0      0          0        0         1         0
# 873         0  47.0      0      0          0        0         1         0
# 874         1  28.0      1      0          1        0         0         1
# 875         1  15.0      0      0          0        0         0         0
# 876         0  20.0      0      0          0        0         1         0
# 877         0  19.0      0      0          0        0         1         0
# 878         0  56.0      0      0          0        0         1         0
# 879         1  56.0      0      1          0        1         0         0
# 880         1  25.0      0      1          0        1         0         1
# 881         0  33.0      0      0          0        0         1         0
# 882         0  22.0      0      0          0        0         0         0
# 883         0  28.0      0      0          0        0         1         1
# 884         0  25.0      0      0          0        0         1         0
# 885         0  39.0      0      5          0        1         0         0
# 886         0  27.0      0      0          0        0         1         1
# 887         1  19.0      0      0          0        0         0         0
# 888         0  26.0      1      2          1        1         0         0
# 889         1  26.0      0      0          0        0         1         0
# 890         0  32.0      0      0          0        0         1         0
#
#      Pclass_3
# 0           1
# 1           0
# 2           1
# 3           0
# 4           1
# 5           1
# 6           0
# 7           1
# 8           1
# 9           0
# 10          1
# 11          0
# 12          1
# 13          1
# 14          1
# 15          0
# 16          1
# 17          0
# 18          1
# 19          1
# 20          0
# 21          0
# 22          1
# 23          0
# 24          1
# 25          1
# 26          1
# 27          0
# 28          1
# 29          1
# ..        ...
# 861         0
# 862         0
# 863         1
# 864         0
# 865         0
# 866         0
# 867         0
# 868         1
# 869         1
# 870         1
# 871         0
# 872         0
# 873         1
# 874         0
# 875         1
# 876         1
# 877         1
# 878         1
# 879         0
# 880         0
# 881         1
# 882         1
# 883         0
# 884         1
# 885         1
# 886         0
# 887         0
# 888         1
# 889         0
# 890         1
#
# [891 rows x 9 columns]

# %%
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch  isSibling  isChild
# 0         0       3    male  22.0      1      0          1        0
# 1         1       1  female  38.0      1      0          1        0
# 2         1       3  female  26.0      0      0          0        0
# 3         1       1  female  35.0      1      0          1        0
# 4         0       3    male  35.0      0      0          0        0

# %%
feature_to_use = ['Age', 'isSibling', 'isChild', 'Sex_male', 'Pclass_2', 'Pclass_3']
X = model_data[feature_to_use]
y = model_data.Survived
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-58-efb1d9601006> in <module>()
#       1 feature_to_use = ['Age', 'isSibling', 'isChild', 'Sex_male', 'Pclass_2', 'Pclass_3']
# ----> 2 X = model_data[feature_to_use]
#       3 y = model_data.Survived
#
# /anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1956         if isinstance(key, (Series, np.ndarray, Index, list)):
#    1957             # either boolean or fancy integer index
# -> 1958             return self._getitem_array(key)
#    1959         elif isinstance(key, DataFrame):
#    1960             return self._getitem_frame(key)
#
# /anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_array(self, key)
#    2000             return self.take(indexer, axis=0, convert=False)
#    2001         else:
# -> 2002             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2003             return self.take(indexer, axis=1, convert=True)
#    2004
#
# /anaconda2/lib/python2.7/site-packages/pandas/core/indexing.pyc in _convert_to_indexer(self, obj, axis, is_setter)
#    1229                 mask = check == -1
#    1230                 if mask.any():
# -> 1231                     raise KeyError('%s not in index' % objarr[mask])
#    1232
#    1233                 return _values_from_object(indexer)
#
# KeyError: "['Sex_male' 'Pclass_2' 'Pclass_3'] not in index"

# %%
lm = LogisticRegression()
lm.fit(X,y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-781b050b2e8c> in <module>()
#       1 lm = LogisticRegression()
# ----> 2 lm.fit(X,y)
#
# NameError: name 'X' is not defined

# %%
print lm.score(X,y)

# %%
probas =
